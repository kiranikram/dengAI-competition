# %%
import pandas as pd
import numpy as np


# data viz
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# apply some cool styling
plt.style.use("ggplot")
rcParams["figure.figsize"] = (12, 6)

# %%
train_features = pd.read_csv("/Users/mussayababbasshamsi/Desktop/Kiran/dengAI-competition/data2/dengue_features_train.csv",index_col=[0, 1, 2])

# %%
train_features.head()
# Out:
#                      week_start_date   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# city year weekofyear
# sj   1990 18              1990-04-30  0.122600  0.103725  0.198483  0.177617
#           19              1990-05-07  0.169900  0.142175  0.162357  0.155486
#           20              1990-05-14  0.032250  0.172967  0.157200  0.170843
#           21              1990-05-21  0.128633  0.245067  0.227557  0.235886
#           22              1990-05-28  0.196200  0.262200  0.251200  0.247340
#
#                       precipitation_amt_mm  reanalysis_air_temp_k  \
# city year weekofyear
# sj   1990 18                         12.42             297.572857
#           19                         22.82             298.211429
#           20                         34.54             298.781429
#           21                         15.36             298.987143
#           22                          7.52             299.518571
#
# ...

# %%
train_features.tail()
# Out:
#                      week_start_date   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# city year weekofyear
# iq   2010 21              2010-05-28  0.342750  0.318900  0.256343  0.292514
#           22              2010-06-04  0.160157  0.160371  0.136043  0.225657
#           23              2010-06-11  0.247057  0.146057  0.250357  0.233714
#           24              2010-06-18  0.333914  0.245771  0.278886  0.325486
#           25              2010-06-25  0.298186  0.232971  0.274214  0.315757
#
#                       precipitation_amt_mm  reanalysis_air_temp_k  \
# city year weekofyear
# iq   2010 21                         55.30             299.334286
#           22                         86.47             298.330000
#           23                         58.94             296.598571
#           24                         59.67             296.345714
#           25                         63.22             298.097143
#
# ...

# %%
train_features.describe().T
# Out:
#                                         count        mean        std  \
# ndvi_ne                                1262.0    0.142294   0.140531
# ndvi_nw                                1404.0    0.130553   0.119999
# ndvi_se                                1434.0    0.203783   0.073860
# ndvi_sw                                1434.0    0.202305   0.083903
# precipitation_amt_mm                   1443.0   45.760388  43.715537
# reanalysis_air_temp_k                  1446.0  298.701852   1.362420
# reanalysis_avg_temp_k                  1446.0  299.225578   1.261715
# reanalysis_dew_point_temp_k            1446.0  295.246356   1.527810
# reanalysis_max_air_temp_k              1446.0  303.427109   3.234601
# reanalysis_min_air_temp_k              1446.0  295.719156   2.565364
# reanalysis_precip_amt_kg_per_m2        1446.0   40.151819  43.434399
# reanalysis_relative_humidity_percent   1446.0   82.161959   7.153897
# reanalysis_sat_precip_amt_mm           1443.0   45.760388  43.715537
# ...

# %%
train_features.isnull().sum()
# Out:
# week_start_date                            0
# ndvi_ne                                  194
# ndvi_nw                                   52
# ndvi_se                                   22
# ndvi_sw                                   22
# precipitation_amt_mm                      13
# reanalysis_air_temp_k                     10
# reanalysis_avg_temp_k                     10
# reanalysis_dew_point_temp_k               10
# reanalysis_max_air_temp_k                 10
# reanalysis_min_air_temp_k                 10
# reanalysis_precip_amt_kg_per_m2           10
# reanalysis_relative_humidity_percent      10
# reanalysis_sat_precip_amt_mm              13
# reanalysis_specific_humidity_g_per_kg     10
# reanalysis_tdtr_k                         10
# station_avg_temp_c                        43
# station_diur_temp_rng_c                   43
# station_max_temp_c                        20
# station_min_temp_c                        14
# station_precip_mm                         22
# ...

# %%
def split_data_by_city(df):
    sj = df.loc['sj']
    iq = df.loc['iq']

    return sj , iq

# %%
sj_features , iq_features = split_data_by_city(train_features)

# %%
num_cols = sj_features.select_dtypes(include=np.number).columns.tolist()


corrmat = sj_features.corr()
hm = sns.heatmap(
    corrmat,
    cbar=True,
    annot=True,
    square=True,
    fmt=".2f",
    annot_kws={"size": 10},
    yticklabels=sj_features.columns,
    xticklabels=sj_features.columns,
    cmap="Spectral_r",
)
plt.show()
# Out:
# /var/folders/xb/0gk7rd0d72sg77xb_s4b6rg00000gn/T/ipykernel_24958/1598902358.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = sj_features.corr()

# %%
sj_features = sj_features[['reanalysis_relative_humidity_percent','station_avg_temp_c','station_min_temp_c','reanalysis_specific_humidity_g_per_kg','reanalysis_dew_point_temp_k']]

# %%
num_cols = sj_features.select_dtypes(include=np.number).columns.tolist()

# %%
for col in num_cols:
    print(col)
    print("Skew :", round(sj_features[col].skew(), 2))
    plt.figure(figsize=(15, 4))
    plt.subplot(1, 2, 1)
    sj_features[col].hist(grid=False)
    plt.ylabel("count")
    plt.subplot(1, 2, 2)
    sns.boxplot(x=sj_features[col])
    plt.show()
# Out:
# reanalysis_relative_humidity_percent
# Skew : -0.19
# station_avg_temp_c
# Skew : -0.31
# station_min_temp_c
# Skew : -0.39
# reanalysis_specific_humidity_g_per_kg
# Skew : -0.47
# reanalysis_dew_point_temp_k
# Skew : -0.63

# %%
num_cols_iq = iq_features.select_dtypes(include=np.number).columns.tolist()


corrmat = iq_features.corr()
hm = sns.heatmap(
    corrmat,
    cbar=True,
    annot=True,
    square=True,
    fmt=".2f",
    annot_kws={"size": 10},
    yticklabels=sj_features.columns,
    xticklabels=sj_features.columns,
    cmap="Spectral_r",
)
plt.show()
# Out:
# /var/folders/xb/0gk7rd0d72sg77xb_s4b6rg00000gn/T/ipykernel_24958/3173435447.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = iq_features.corr()

# %%
iq_features = iq_features[['reanalysis_relative_humidity_percent','station_avg_temp_c','station_min_temp_c','reanalysis_specific_humidity_g_per_kg','reanalysis_dew_point_temp_k']]
num_cols_iq = iq_features.select_dtypes(include=np.number).columns.tolist()

# %%
for col in num_cols_iq:
    print(col)
    print("Skew :", round(sj_features[col].skew(), 2))
    plt.figure(figsize=(15, 4))
    plt.subplot(1, 2, 1)
    sj_features[col].hist(grid=False)
    plt.ylabel("count")
    plt.subplot(1, 2, 2)
    sns.boxplot(x=sj_features[col])
    plt.show()
# Out:
# reanalysis_relative_humidity_percent
# Skew : -0.19
# station_avg_temp_c
# Skew : -0.31
# station_min_temp_c
# Skew : -0.39
# reanalysis_specific_humidity_g_per_kg
# Skew : -0.47
# reanalysis_dew_point_temp_k
# Skew : -0.63
